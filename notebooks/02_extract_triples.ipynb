# %%
# %cd ..
# Out:
# D:\qa\qasper-kg-rag
# C:\Users\navin\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import sys
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------- -------------------------- 4.5/12.8 MB 29.7 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 36.5 MB/s  0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
  # %run scripts/extract_triples.py --input data/processed/paragraphs.jsonl --output data/triples/triples.jsonl --max_rows 5
# Out:
# Initializing local LLM extractor using model: llama3
# Extracting triples:   0%|                                                                        | 0/5 [00:00<?, ?it/s]
# [RAW LLM OUTPUT for 'Affective events BIBREF0 are e...']: {'data': [{'subject': 'Affective events', 'relation': 'AFFECT', 'object': 'people'}, {'subject': 'Affective events', 'relation': 'EVALUATE_TO', 'object': 'positive or negative ways'}]}
#
# [RAW LLM OUTPUT for 'For example, getting money and...']: {'data': [{'subject': 'getting money', 'relation': 'IS_POSITIVE_TO', 'object': 'experiencers'}, {'subject': 'playing sports', 'relation': 'IS_POSITIVE_TO', 'object': 'experiencers'}, {'subject': 'catching cold', 'relation': 'IS_NEGATIVE_TO', 'object': 'experiencers'}, {'subject': "losing one's wallet", 'relation': 'IS_NEGATIVE_TO', 'object': 'experiencers'}]}
#
# ...

# %%
from pathlib import Path
print(Path("data/triples/triples.jsonl").exists())
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'D:\\qa\\qasper-kg-rag'
