# %%
# %cd ..
# Out:
# D:\qa\qasper-kg-rag
# C:\Users\navin\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %run scripts/evaluate.py --qas data/raw/qasper_eval_qas.jsonl --max_questions 100 --top_k 5 --output data/processed/predictions.jsonl
# Out:
# ...
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 100/100 [00:28<00:00,  3.53it/s]
# Exact Match: 0.0000
# F1:          0.0624
# Saved predictions to data\processed\predictions.jsonl

# %%
from pathlib import Path
print(Path("data/processed/predictions.jsonl").exists())
# Out:
# True
